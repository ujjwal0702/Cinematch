# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Now We'll Extract the features of 2018 movies from Wikipedia

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2018"
df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

# %%
df1.head()
# Out:
#          Opening  Opening.1                    Title  \
# 0  J A N U A R Y          5  Insidious: The Last Key
# 1  J A N U A R Y          5         The Strange Ones
# 2  J A N U A R Y         12             The Commuter
# 3  J A N U A R Y         12               Proud Mary
# 4  J A N U A R Y         12         Acts of Violence
#
#                                   Production company  \
# 0  Universal Pictures / Blumhouse Productions / S...
# 1                             Vertical Entertainment
# 2      Lionsgate / StudioCanal / The Picture Company
# 3                                        Screen Gems
# 4                                 Lionsgate Premiere
#
#                                        Cast and crew  \
# 0  Adam Robitel (director); Leigh Whannell (scree...
# 1  Christopher Radcliff (director/screenplay); La...
# 2  Jaume Collet-Serra (director); Byron Willinger...
# 3  Babak Najafi (director); John S. Newman, Chris...
# 4  Brett Donowho (director); Nicolas Aaron Mezzan...
#
#   .mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}Ref.
# 0                                                [2]
# 1                                                [3]
# 2                                                [4]
# 3                                                [5]
# 4                                                [6]

# %%
# Now we'll combine all the dataframe
pair1=pd.concat([df3,df4],axis=0,ignore_index=True)
pair2=pd.concat([df2,pair1],axis=0,ignore_index=True)
df=pd.concat([df1,pair2],axis=0,ignore_index=True)

# %%
df
# Out:
#              Opening  Opening.1                    Title  \
# 0      J A N U A R Y          5  Insidious: The Last Key
# 1      J A N U A R Y          5         The Strange Ones
# 2      J A N U A R Y         12             The Commuter
# 3      J A N U A R Y         12               Proud Mary
# 4      J A N U A R Y         12         Acts of Violence
# ..               ...        ...                      ...
# 241  D E C E M B E R         21               Second Act
# 242  D E C E M B E R         25          Holmes & Watson
# 243  D E C E M B E R         25                     Vice
# 244  D E C E M B E R         25      On the Basis of Sex
# 245  D E C E M B E R         25                Destroyer
#
#                                     Production company  \
# 0    Universal Pictures / Blumhouse Productions / S...
# 1                               Vertical Entertainment
# 2        Lionsgate / StudioCanal / The Picture Company
# 3                                          Screen Gems
# 4                                   Lionsgate Premiere
# ..                                                 ...
# 241                                  STX Entertainment
# 242  Columbia Pictures / Gary Sanchez Productions /...
# 243          Annapurna Pictures / Plan B Entertainment
# 244                                     Focus Features
# 245                                 Annapurna Pictures
#
#                                          Cast and crew  \
# 0    Adam Robitel (director); Leigh Whannell (scree...
# 1    Christopher Radcliff (director/screenplay); La...
# 2    Jaume Collet-Serra (director); Byron Willinger...
# 3    Babak Najafi (director); John S. Newman, Chris...
# 4    Brett Donowho (director); Nicolas Aaron Mezzan...
# ..                                                 ...
# 241  Peter Segal (director); Justin Zackham, Elaine...
# 242  Etan Cohen (director/screenplay); Will Ferrell...
# 243  Adam McKay (director/screenplay); Christian Ba...
# 244  Mimi Leder (director); Daniel Stiepleman (scre...
# 245  Karyn Kusama (director); Phil Hay, Matt Manfre...
#
#     .mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}Ref.  \
# 0                                                  [2]
# 1                                                  [3]
# 2                                                  [4]
# 3                                                  [5]
# 4                                                  [6]
# ..                                                 ...
# 241                                                NaN
# 242                                                NaN
# 243                                                NaN
# 244                                                NaN
# 245                                                NaN
#
#       Ref.
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ..     ...
# 241  [235]
# 242  [141]
# 243  [116]
# 244  [206]
# 245  [236]
#
# [246 rows x 7 columns]

# %%
from tmdbv3api import TMDb
import json
import requests
tmdb = TMDb()
tmdb.api_key = '729fcde16e57db670079f06107ea69bc'

# %%
from tmdbv3api import Movie
tmdb_movie = Movie()
def get_genre(x):
    genres = []
    result = tmdb_movie.search(x)
    movie_id = result[0].id
    response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
    data_json = response.json()
    if data_json['genres']:
        genre_str = ' '
        for i in range(0,len(data_json['genres'])):
            genres.append(data_json['genres'][i]['name'])
        return genre_str.join(genres)
    else:  
        np.NaN

# %%
df['genres'] = df['Title'].map(lambda x: get_genre(str(x)))

# %%
df
# Out:
#              Opening  Opening.1                    Title  \
# 0      J A N U A R Y          5  Insidious: The Last Key
# 1      J A N U A R Y          5         The Strange Ones
# 2      J A N U A R Y         12             The Commuter
# 3      J A N U A R Y         12               Proud Mary
# 4      J A N U A R Y         12         Acts of Violence
# ..               ...        ...                      ...
# 241  D E C E M B E R         21               Second Act
# 242  D E C E M B E R         25          Holmes & Watson
# 243  D E C E M B E R         25                     Vice
# 244  D E C E M B E R         25      On the Basis of Sex
# 245  D E C E M B E R         25                Destroyer
#
#                                     Production company  \
# 0    Universal Pictures / Blumhouse Productions / S...
# 1                               Vertical Entertainment
# 2        Lionsgate / StudioCanal / The Picture Company
# 3                                          Screen Gems
# 4                                   Lionsgate Premiere
# ..                                                 ...
# 241                                  STX Entertainment
# 242  Columbia Pictures / Gary Sanchez Productions /...
# 243          Annapurna Pictures / Plan B Entertainment
# 244                                     Focus Features
# 245                                 Annapurna Pictures
#
#                                          Cast and crew  \
# 0    Adam Robitel (director); Leigh Whannell (scree...
# 1    Christopher Radcliff (director/screenplay); La...
# 2    Jaume Collet-Serra (director); Byron Willinger...
# 3    Babak Najafi (director); John S. Newman, Chris...
# 4    Brett Donowho (director); Nicolas Aaron Mezzan...
# ..                                                 ...
# 241  Peter Segal (director); Justin Zackham, Elaine...
# 242  Etan Cohen (director/screenplay); Will Ferrell...
# 243  Adam McKay (director/screenplay); Christian Ba...
# 244  Mimi Leder (director); Daniel Stiepleman (scre...
# 245  Karyn Kusama (director); Phil Hay, Matt Manfre...
#
#     .mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}Ref.  \
# 0                                                  [2]
# 1                                                  [3]
# 2                                                  [4]
# 3                                                  [5]
# 4                                                  [6]
# ..                                                 ...
# 241                                                NaN
# 242                                                NaN
# 243                                                NaN
# 244                                                NaN
# 245                                                NaN
#
#       Ref.                          genres
# 0      NaN         Horror Mystery Thriller
# 1      NaN                   Drama Mystery
# 2      NaN         Action Thriller Mystery
# 3      NaN           Thriller Action Crime
# 4      NaN           Action Crime Thriller
# ..     ...                             ...
# 241  [235]                  Romance Comedy
# 242  [141]  Mystery Adventure Comedy Crime
# 243  [116]                    Comedy Drama
# 244  [206]                   Drama History
# 245  [236]     Thriller Crime Drama Action
#
# [246 rows x 8 columns]

# %%
df_2018 = df[['Title','Cast and crew','genres']]

# %%
df_2018
# Out:
#                        Title  \
# 0    Insidious: The Last Key
# 1           The Strange Ones
# 2               The Commuter
# 3                 Proud Mary
# 4           Acts of Violence
# ..                       ...
# 241               Second Act
# 242          Holmes & Watson
# 243                     Vice
# 244      On the Basis of Sex
# 245                Destroyer
#
#                                          Cast and crew  \
# 0    Adam Robitel (director); Leigh Whannell (scree...
# 1    Christopher Radcliff (director/screenplay); La...
# 2    Jaume Collet-Serra (director); Byron Willinger...
# 3    Babak Najafi (director); John S. Newman, Chris...
# 4    Brett Donowho (director); Nicolas Aaron Mezzan...
# ..                                                 ...
# 241  Peter Segal (director); Justin Zackham, Elaine...
# 242  Etan Cohen (director/screenplay); Will Ferrell...
# 243  Adam McKay (director/screenplay); Christian Ba...
# 244  Mimi Leder (director); Daniel Stiepleman (scre...
# 245  Karyn Kusama (director); Phil Hay, Matt Manfre...
#
#                              genres
# 0           Horror Mystery Thriller
# 1                     Drama Mystery
# 2           Action Thriller Mystery
# 3             Thriller Action Crime
# 4             Action Crime Thriller
# ..                              ...
# 241                  Romance Comedy
# 242  Mystery Adventure Comedy Crime
# 243                    Comedy Drama
# 244                   Drama History
# 245     Thriller Crime Drama Action
#
# [246 rows x 3 columns]

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2018['director_name'] = df_2018['Cast and crew'].map(lambda x: get_director(x))
# Out:
# /tmp/ipykernel_1075/930721595.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018['director_name'] = df_2018['Cast and crew'].map(lambda x: get_director(x))

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2018['actor_1_name'] = df_2018['Cast and crew'].map(lambda x: get_actor1(x))
# Out:
# /tmp/ipykernel_1075/2274966287.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018['actor_1_name'] = df_2018['Cast and crew'].map(lambda x: get_actor1(x))

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2018['actor_2_name'] = df_2018['Cast and crew'].map(lambda x: get_actor2(x))
# Out:
# /tmp/ipykernel_1075/3672495884.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018['actor_2_name'] = df_2018['Cast and crew'].map(lambda x: get_actor2(x))

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2018['actor_3_name'] = df_2018['Cast and crew'].map(lambda x: get_actor3(x))
# Out:
# /tmp/ipykernel_1075/2517195254.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018['actor_3_name'] = df_2018['Cast and crew'].map(lambda x: get_actor3(x))

# %%
df_2018
# Out:
#                        Title  \
# 0    Insidious: The Last Key
# 1           The Strange Ones
# 2               The Commuter
# 3                 Proud Mary
# 4           Acts of Violence
# ..                       ...
# 241               Second Act
# 242          Holmes & Watson
# 243                     Vice
# 244      On the Basis of Sex
# 245                Destroyer
#
#                                          Cast and crew  \
# 0    Adam Robitel (director); Leigh Whannell (scree...
# 1    Christopher Radcliff (director/screenplay); La...
# 2    Jaume Collet-Serra (director); Byron Willinger...
# 3    Babak Najafi (director); John S. Newman, Chris...
# 4    Brett Donowho (director); Nicolas Aaron Mezzan...
# ..                                                 ...
# 241  Peter Segal (director); Justin Zackham, Elaine...
# 242  Etan Cohen (director/screenplay); Will Ferrell...
# 243  Adam McKay (director/screenplay); Christian Ba...
# 244  Mimi Leder (director); Daniel Stiepleman (scre...
# 245  Karyn Kusama (director); Phil Hay, Matt Manfre...
#
#                              genres  \
# 0           Horror Mystery Thriller
# 1                     Drama Mystery
# 2           Action Thriller Mystery
# 3             Thriller Action Crime
# 4             Action Crime Thriller
# ..                              ...
# 241                  Romance Comedy
# 242  Mystery Adventure Comedy Crime
# 243                    Comedy Drama
# 244                   Drama History
# 245     Thriller Crime Drama Action
#
#                                          director_name  \
# 0                                         Adam Robitel
# 1    Christopher Radcliff (director/screenplay); La...
# 2                                   Jaume Collet-Serra
# 3                                         Babak Najafi
# 4                                        Brett Donowho
# ..                                                 ...
# 241                                        Peter Segal
# 242                                         Etan Cohen
# 243                                         Adam McKay
# 244                                         Mimi Leder
# 245                                       Karyn Kusama
#
#                                    actor_1_name            actor_2_name  \
# 0                                     Lin Shaye           Angus Sampson
# 1    Lauren Wolkstein (director); Alex Pettyfer  James Freedson-Jackson
# 2                                   Liam Neeson            Vera Farmiga
# 3                              Taraji P. Henson    Jahi Di'Allo Winston
# 4                                  Bruce Willis             Cole Hauser
# ..                                          ...                     ...
# 241                              Jennifer Lopez             Leah Remini
# 242                                Will Ferrell          John C. Reilly
# 243                              Christian Bale               Amy Adams
# 244                              Felicity Jones            Armie Hammer
# 245                               Nicole Kidman          Sebastian Stan
#
#         actor_3_name
# 0     Leigh Whannell
# 1      Emily Althaus
# 2     Patrick Wilson
# 3        Billy Brown
# 4      Shawn Ashmore
# ..               ...
# 241  Vanessa Hudgens
# 242     Rebecca Hall
# 243     Steve Carell
# 244   Justin Theroux
# 245     Toby Kebbell
#
# [246 rows x 7 columns]

# %%
df_2018 = df_2018.rename(columns={'Title':'movie_title'})

# %%
new_df18 = df_2018.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df18
# Out:
#                                          director_name  \
# 0                                         Adam Robitel
# 1    Christopher Radcliff (director/screenplay); La...
# 2                                   Jaume Collet-Serra
# 3                                         Babak Najafi
# 4                                        Brett Donowho
# ..                                                 ...
# 241                                        Peter Segal
# 242                                         Etan Cohen
# 243                                         Adam McKay
# 244                                         Mimi Leder
# 245                                       Karyn Kusama
#
#                                    actor_1_name            actor_2_name  \
# 0                                     Lin Shaye           Angus Sampson
# 1    Lauren Wolkstein (director); Alex Pettyfer  James Freedson-Jackson
# 2                                   Liam Neeson            Vera Farmiga
# 3                              Taraji P. Henson    Jahi Di'Allo Winston
# 4                                  Bruce Willis             Cole Hauser
# ..                                          ...                     ...
# 241                              Jennifer Lopez             Leah Remini
# 242                                Will Ferrell          John C. Reilly
# 243                              Christian Bale               Amy Adams
# 244                              Felicity Jones            Armie Hammer
# 245                               Nicole Kidman          Sebastian Stan
#
#         actor_3_name                          genres              movie_title
# 0     Leigh Whannell         Horror Mystery Thriller  Insidious: The Last Key
# 1      Emily Althaus                   Drama Mystery         The Strange Ones
# 2     Patrick Wilson         Action Thriller Mystery             The Commuter
# 3        Billy Brown           Thriller Action Crime               Proud Mary
# 4      Shawn Ashmore           Action Crime Thriller         Acts of Violence
# ..               ...                             ...                      ...
# 241  Vanessa Hudgens                  Romance Comedy               Second Act
# 242     Rebecca Hall  Mystery Adventure Comedy Crime          Holmes & Watson
# 243     Steve Carell                    Comedy Drama                     Vice
# 244   Justin Theroux                   Drama History      On the Basis of Sex
# 245     Toby Kebbell     Thriller Crime Drama Action                Destroyer
#
# [246 rows x 6 columns]

# %%
new_df18.isna().sum()
# Out:
# director_name     0
# actor_1_name      0
# actor_2_name      4
# actor_3_name     15
# genres            0
# movie_title       0
# dtype: int64

# %%
new_df18['actor_2_name'] = new_df18['actor_2_name'].replace(np.nan, 'unknown')
new_df18['actor_3_name'] = new_df18['actor_3_name'].replace(np.nan, 'unknown')

# %%
new_df18['movie_title'] = new_df18['movie_title'].str.lower()

# %%
new_df18['comb'] = new_df18['actor_1_name'] + ' ' + new_df18['actor_2_name'] + ' '+ new_df18['actor_3_name'] + ' '+ new_df18['director_name'] +' ' + new_df18['genres']

# %%
new_df18
# Out:
#                                          director_name  \
# 0                                         Adam Robitel
# 1    Christopher Radcliff (director/screenplay); La...
# 2                                   Jaume Collet-Serra
# 3                                         Babak Najafi
# 4                                        Brett Donowho
# ..                                                 ...
# 241                                        Peter Segal
# 242                                         Etan Cohen
# 243                                         Adam McKay
# 244                                         Mimi Leder
# 245                                       Karyn Kusama
#
#                                    actor_1_name            actor_2_name  \
# 0                                     Lin Shaye           Angus Sampson
# 1    Lauren Wolkstein (director); Alex Pettyfer  James Freedson-Jackson
# 2                                   Liam Neeson            Vera Farmiga
# 3                              Taraji P. Henson    Jahi Di'Allo Winston
# 4                                  Bruce Willis             Cole Hauser
# ..                                          ...                     ...
# 241                              Jennifer Lopez             Leah Remini
# 242                                Will Ferrell          John C. Reilly
# 243                              Christian Bale               Amy Adams
# 244                              Felicity Jones            Armie Hammer
# 245                               Nicole Kidman          Sebastian Stan
#
#         actor_3_name                          genres              movie_title  \
# 0     Leigh Whannell         Horror Mystery Thriller  insidious: the last key
# 1      Emily Althaus                   Drama Mystery         the strange ones
# 2     Patrick Wilson         Action Thriller Mystery             the commuter
# 3        Billy Brown           Thriller Action Crime               proud mary
# 4      Shawn Ashmore           Action Crime Thriller         acts of violence
# ..               ...                             ...                      ...
# 241  Vanessa Hudgens                  Romance Comedy               second act
# 242     Rebecca Hall  Mystery Adventure Comedy Crime          holmes & watson
# 243     Steve Carell                    Comedy Drama                     vice
# 244   Justin Theroux                   Drama History      on the basis of sex
# 245     Toby Kebbell     Thriller Crime Drama Action                destroyer
#
#                                                   comb
# 0    Lin Shaye Angus Sampson Leigh Whannell Adam Ro...
# 1    Lauren Wolkstein (director); Alex Pettyfer Jam...
# 2    Liam Neeson Vera Farmiga Patrick Wilson Jaume ...
# 3    Taraji P. Henson Jahi Di'Allo Winston Billy Br...
# 4    Bruce Willis Cole Hauser Shawn Ashmore Brett D...
# ..                                                 ...
# 241  Jennifer Lopez Leah Remini Vanessa Hudgens Pet...
# 242  Will Ferrell John C. Reilly Rebecca Hall Etan ...
# 243  Christian Bale Amy Adams Steve Carell Adam McK...
# 244  Felicity Jones Armie Hammer Justin Theroux Mim...
# 245  Nicole Kidman Sebastian Stan Toby Kebbell Kary...
#
# [246 rows x 7 columns]

# %% [markdown]
# ## Extracting Features of 2019 movies from Wikipedia

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2019"
df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

# %%
p1=pd.concat([df3,df4],axis=0,ignore_index=True)
p2=pd.concat([p1,df2],axis=0,ignore_index=True)
df=pd.concat([p2,df1],axis=0,ignore_index=True)

# %%
df
# Out:
#        Opening  Opening.1                        Title  \
# 0      J U L Y          2    Spider-Man: Far From Home
# 1      J U L Y          2  Escape Plan: The Extractors
# 2      J U L Y         12                    Midsommar
# 3      J U L Y         12                       Stuber
# 4      J U L Y         12                        Crawl
# ..         ...        ...                          ...
# 242  M A R C H         22                     The Dirt
# 243  M A R C H         22      Dragged Across Concrete
# 244  M A R C H         29                        Dumbo
# 245  M A R C H         29                The Beach Bum
# 246  M A R C H         29                    Unplanned
#
#                             Production company  \
# 0           Columbia Pictures / Marvel Studios
# 1                         Summit Entertainment
# 2                                          A24
# 3                             20th Century Fox
# 4    Paramount Pictures / Ghost House Pictures
# ..                                         ...
# 242                                    Netflix
# 243                       Summit Entertainment
# 244                       Walt Disney Pictures
# 245                                       Neon
# 246                                  Pure Flix
#
#                                          Cast and crew   Ref.
# 0    Jon Watts (director); Chris McKenna, Erik Somm...  [113]
# 1    John Herzfeld (director); John Herzfeld, Miles...  [114]
# 2    Ari Aster (director/screenplay); Florence Pugh...  [115]
# 3    Michael Dowse (director); Tripper Clancy (scre...  [116]
# 4    Alexandre Aja (director); Shawn Rasmussen, Mic...  [117]
# ..                                                 ...    ...
# 242  Jeff Tremaine (director): Tom Kapinos, Amanda ...   [45]
# 243  S. Craig Zahler (director/screenplay); Mel Gib...   [46]
# 244  Tim Burton (director); Ehren Kruger (screenpla...   [47]
# 245  Harmony Korine (director/screenplay); Matthew ...   [48]
# 246  Chuck Konzelman, Cary Soloman (director/screen...   [49]
#
# [247 rows x 6 columns]

# %%
df['genres'] = df['Title'].map(lambda x: get_genre(str(x)))

# %%
df_2019 = df[['Title','Cast and crew','genres']]

# %%
df_2019
# Out:
#                            Title  \
# 0      Spider-Man: Far From Home
# 1    Escape Plan: The Extractors
# 2                      Midsommar
# 3                         Stuber
# 4                          Crawl
# ..                           ...
# 242                     The Dirt
# 243      Dragged Across Concrete
# 244                        Dumbo
# 245                The Beach Bum
# 246                    Unplanned
#
#                                          Cast and crew  \
# 0    Jon Watts (director); Chris McKenna, Erik Somm...
# 1    John Herzfeld (director); John Herzfeld, Miles...
# 2    Ari Aster (director/screenplay); Florence Pugh...
# 3    Michael Dowse (director); Tripper Clancy (scre...
# 4    Alexandre Aja (director); Shawn Rasmussen, Mic...
# ..                                                 ...
# 242  Jeff Tremaine (director): Tom Kapinos, Amanda ...
# 243  S. Craig Zahler (director/screenplay); Mel Gib...
# 244  Tim Burton (director); Ehren Kruger (screenpla...
# 245  Harmony Korine (director/screenplay); Matthew ...
# 246  Chuck Konzelman, Cary Soloman (director/screen...
#
#                                genres
# 0    Action Adventure Science Fiction
# 1               Action Crime Thriller
# 2                Horror Drama Mystery
# 3                       Action Comedy
# 4              Thriller Horror Action
# ..                                ...
# 242        Drama Music History Comedy
# 243             Crime Action Thriller
# 244                  Animation Family
# 245                            Comedy
# 246                      Drama Horror
#
# [247 rows x 3 columns]

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2019['director_name'] = df_2019['Cast and crew'].map(lambda x: get_director(str(x)))
# Out:
# /tmp/ipykernel_1075/203239715.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2019['director_name'] = df_2019['Cast and crew'].map(lambda x: get_director(str(x)))

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2019['actor_1_name'] = df_2019['Cast and crew'].map(lambda x: get_actor1(x))
# Out:
# /tmp/ipykernel_1075/1562076556.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2019['actor_1_name'] = df_2019['Cast and crew'].map(lambda x: get_actor1(x))

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2019['actor_2_name'] = df_2019['Cast and crew'].map(lambda x: get_actor2(x))
# Out:
# /tmp/ipykernel_1075/3736213850.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2019['actor_2_name'] = df_2019['Cast and crew'].map(lambda x: get_actor2(x))

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2019['actor_3_name'] = df_2019['Cast and crew'].map(lambda x: get_actor3(x))

# %%
df_2019 = df_2019.rename(columns={'Title':'movie_title'})

# %%
new_df19 = df_2019.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
df_2019.isnull().sum()
# Out:
# movie_title       0
# Cast and crew     0
# genres            0
# director_name     0
# actor_1_name      0
# actor_2_name      1
# actor_3_name     17
# dtype: int64

# %%
new_df19['actor_2_name'] = new_df19['actor_2_name'].replace(np.nan, 'unknown')
new_df19['actor_3_name'] = new_df19['actor_3_name'].replace(np.nan, 'unknown')

# %%
new_df19['movie_title'] = new_df19['movie_title'].str.lower()

# %%
new_df19['comb'] = new_df19['actor_1_name'] + ' ' + new_df19['actor_2_name'] + ' '+ new_df19['actor_3_name'] + ' '+ new_df19['director_name'] +' ' + new_df19['genres']

# %%
new_df19
# Out:
#                      director_name         actor_1_name       actor_2_name  \
# 0                        Jon Watts          Tom Holland  Samuel L. Jackson
# 1                    John Herzfeld   Sylvester Stallone     Curtis Jackson
# 2                        Ari Aster        Florence Pugh        Jack Reynor
# 3                    Michael Dowse      Kumail Nanjiani      Dave Bautista
# 4                    Alexandre Aja      Kaya Scodelario       Barry Pepper
# ..                             ...                  ...                ...
# 242                  Jeff Tremaine        Douglas Booth         Iwan Rheon
# 243                S. Craig Zahler           Mel Gibson       Vince Vaughn
# 244                     Tim Burton        Colin Farrell     Michael Keaton
# 245                 Harmony Korine  Matthew McConaughey          Zac Efron
# 246  Chuck Konzelman, Cary Soloman      Ashley Bratcher        Brooks Ryan
#
#                actor_3_name                            genres  \
# 0                   Zendaya  Action Adventure Science Fiction
# 1             Dave Bautista             Action Crime Thriller
# 2    William Jackson Harper              Horror Drama Mystery
# 3                 Iko Uwais                     Action Comedy
# 4                   unknown            Thriller Horror Action
# ..                      ...                               ...
# 242       Machine Gun Kelly        Drama Music History Comedy
# 243       Michael Jai White             Crime Action Thriller
# 244            Danny DeVito                  Animation Family
# 245              Jonah Hill                            Comedy
# 246             Robia Scott                      Drama Horror
#
#                      movie_title  \
# 0      spider-man: far from home
# 1    escape plan: the extractors
# 2                      midsommar
# 3                         stuber
# 4                          crawl
# ..                           ...
# 242                     the dirt
# 243      dragged across concrete
# 244                        dumbo
# 245                the beach bum
# 246                    unplanned
#
#                                                   comb
# 0    Tom Holland Samuel L. Jackson Zendaya Jon Watt...
# 1    Sylvester Stallone Curtis Jackson Dave Bautist...
# 2    Florence Pugh Jack Reynor William Jackson Harp...
# 3    Kumail Nanjiani Dave Bautista Iko Uwais Michae...
# 4    Kaya Scodelario Barry Pepper unknown Alexandre...
# ..                                                 ...
# 242  Douglas Booth Iwan Rheon Machine Gun Kelly Jef...
# 243  Mel Gibson Vince Vaughn Michael Jai White S. C...
# 244  Colin Farrell Michael Keaton Danny DeVito Tim ...
# 245  Matthew McConaughey Zac Efron Jonah Hill Harmo...
# 246  Ashley Bratcher Brooks Ryan Robia Scott Chuck ...
#
# [247 rows x 7 columns]

# %%
my_df = pd.concat([new_df18,new_df19],ignore_index=True)

# %%
my_df
# Out:
#                                          director_name  \
# 0                                         Adam Robitel
# 1    Christopher Radcliff (director/screenplay); La...
# 2                                   Jaume Collet-Serra
# 3                                         Babak Najafi
# 4                                        Brett Donowho
# ..                                                 ...
# 488                                      Jeff Tremaine
# 489                                    S. Craig Zahler
# 490                                         Tim Burton
# 491                                     Harmony Korine
# 492                      Chuck Konzelman, Cary Soloman
#
#                                    actor_1_name            actor_2_name  \
# 0                                     Lin Shaye           Angus Sampson
# 1    Lauren Wolkstein (director); Alex Pettyfer  James Freedson-Jackson
# 2                                   Liam Neeson            Vera Farmiga
# 3                              Taraji P. Henson    Jahi Di'Allo Winston
# 4                                  Bruce Willis             Cole Hauser
# ..                                          ...                     ...
# 488                               Douglas Booth              Iwan Rheon
# 489                                  Mel Gibson            Vince Vaughn
# 490                               Colin Farrell          Michael Keaton
# 491                         Matthew McConaughey               Zac Efron
# 492                             Ashley Bratcher             Brooks Ryan
#
#           actor_3_name                      genres              movie_title  \
# 0       Leigh Whannell     Horror Mystery Thriller  insidious: the last key
# 1        Emily Althaus               Drama Mystery         the strange ones
# 2       Patrick Wilson     Action Thriller Mystery             the commuter
# 3          Billy Brown       Thriller Action Crime               proud mary
# 4        Shawn Ashmore       Action Crime Thriller         acts of violence
# ..                 ...                         ...                      ...
# 488  Machine Gun Kelly  Drama Music History Comedy                 the dirt
# 489  Michael Jai White       Crime Action Thriller  dragged across concrete
# 490       Danny DeVito            Animation Family                    dumbo
# 491         Jonah Hill                      Comedy            the beach bum
# 492        Robia Scott                Drama Horror                unplanned
#
#                                                   comb
# 0    Lin Shaye Angus Sampson Leigh Whannell Adam Ro...
# 1    Lauren Wolkstein (director); Alex Pettyfer Jam...
# 2    Liam Neeson Vera Farmiga Patrick Wilson Jaume ...
# 3    Taraji P. Henson Jahi Di'Allo Winston Billy Br...
# 4    Bruce Willis Cole Hauser Shawn Ashmore Brett D...
# ..                                                 ...
# 488  Douglas Booth Iwan Rheon Machine Gun Kelly Jef...
# 489  Mel Gibson Vince Vaughn Michael Jai White S. C...
# 490  Colin Farrell Michael Keaton Danny DeVito Tim ...
# 491  Matthew McConaughey Zac Efron Jonah Hill Harmo...
# 492  Ashley Bratcher Brooks Ryan Robia Scott Chuck ...
#
# [493 rows x 7 columns]

# %%
old_df = pd.read_csv('new_data.csv')

# %%
old_df
# Out:
#               director_name          actor_1_name            actor_2_name  \
# 0               CCH Pounder           CCH Pounder             CCH Pounder
# 1               Johnny Depp           Johnny Depp             Johnny Depp
# 2           Christoph Waltz       Christoph Waltz         Christoph Waltz
# 3                 Tom Hardy             Tom Hardy               Tom Hardy
# 4               Doug Walker           Doug Walker             Doug Walker
# ...                     ...                   ...                     ...
# 5354            Jim Strouse      Jessica Williams            Chris O'Dowd
# 5355            Farhad Mann         Adelaide Kane  Benjamin Hollingsworth
# 5356       Hannaleena Hauru        Inka Haapamäki           Rosa Honkonen
# 5357  Jonathan A. Rosenbaum  Lou Diamond Phillips           Wallace Shawn
# 5358           Ravi Udyawar        Sridevi Kapoor               Sajal Ali
#
#            actor_3_name                           genres  \
# 0           CCH Pounder  Action Adventure Fantasy Sci-Fi
# 1           Johnny Depp         Action Adventure Fantasy
# 2       Christoph Waltz        Action Adventure Thriller
# 3             Tom Hardy                  Action Thriller
# 4           Doug Walker                      Documentary
# ...                 ...                              ...
# 5354    Keith Stanfield                    RomanceComedy
# 5355  Jean Louisa Kelly                          Romance
# 5356     Tiitus Rantala                    RomanceComedy
# 5357        Gina Holden          CrimeComedyActionFamily
# 5358     Akshaye Khanna               CrimeDramaThriller
#
#                                             movie_title  \
# 0                                                avatar
# 1              pirates of the caribbean: at world's end
# 2                                               spectre
# 3                                 the dark knight rises
# 4     star wars: episode vii - the force awakens    ...
# ...                                                 ...
# 5354                       the incredible jessica james
# 5355                                  can't buy my love
# 5356                   thick lashes of lauri mäntyvaara
# 5357                        cop and a half: new recruit
# 5358                                                mom
#
#                                                    comb
# 0     CCH Pounder CCH Pounder CCH Pounder CCH Pounde...
# 1     Johnny Depp Johnny Depp Johnny Depp Johnny Dep...
# 2     Christoph Waltz Christoph Waltz Christoph Walt...
# 3     Tom Hardy Tom Hardy Tom Hardy Tom Hardy Action...
# 4     Doug Walker Doug Walker Doug Walker Doug Walke...
# ...                                                 ...
# 5354  Jessica Williams Chris O'Dowd Keith Stanfield ...
# 5355  Adelaide Kane Benjamin Hollingsworth Jean Loui...
# 5356  Inka Haapamäki Rosa Honkonen Tiitus Rantala Ha...
# 5357  Lou Diamond Phillips Wallace Shawn Gina Holden...
# 5358  Sridevi Kapoor Sajal Ali Akshaye Khanna Ravi U...
#
# [5359 rows x 7 columns]

# %%
final_df = pd.concat([old_df,my_df],ignore_index=True)

# %%
final_df
# Out:
#                       director_name         actor_1_name     actor_2_name  \
# 0                       CCH Pounder          CCH Pounder      CCH Pounder
# 1                       Johnny Depp          Johnny Depp      Johnny Depp
# 2                   Christoph Waltz      Christoph Waltz  Christoph Waltz
# 3                         Tom Hardy            Tom Hardy        Tom Hardy
# 4                       Doug Walker          Doug Walker      Doug Walker
# ...                             ...                  ...              ...
# 5847                  Jeff Tremaine        Douglas Booth       Iwan Rheon
# 5848                S. Craig Zahler           Mel Gibson     Vince Vaughn
# 5849                     Tim Burton        Colin Farrell   Michael Keaton
# 5850                 Harmony Korine  Matthew McConaughey        Zac Efron
# 5851  Chuck Konzelman, Cary Soloman      Ashley Bratcher      Brooks Ryan
#
#            actor_3_name                           genres  \
# 0           CCH Pounder  Action Adventure Fantasy Sci-Fi
# 1           Johnny Depp         Action Adventure Fantasy
# 2       Christoph Waltz        Action Adventure Thriller
# 3             Tom Hardy                  Action Thriller
# 4           Doug Walker                      Documentary
# ...                 ...                              ...
# 5847  Machine Gun Kelly       Drama Music History Comedy
# 5848  Michael Jai White            Crime Action Thriller
# 5849       Danny DeVito                 Animation Family
# 5850         Jonah Hill                           Comedy
# 5851        Robia Scott                     Drama Horror
#
#                                             movie_title  \
# 0                                                avatar
# 1              pirates of the caribbean: at world's end
# 2                                               spectre
# 3                                 the dark knight rises
# 4     star wars: episode vii - the force awakens    ...
# ...                                                 ...
# 5847                                           the dirt
# 5848                            dragged across concrete
# 5849                                              dumbo
# 5850                                      the beach bum
# 5851                                          unplanned
#
#                                                    comb
# 0     CCH Pounder CCH Pounder CCH Pounder CCH Pounde...
# 1     Johnny Depp Johnny Depp Johnny Depp Johnny Dep...
# 2     Christoph Waltz Christoph Waltz Christoph Walt...
# 3     Tom Hardy Tom Hardy Tom Hardy Tom Hardy Action...
# 4     Doug Walker Doug Walker Doug Walker Doug Walke...
# ...                                                 ...
# 5847  Douglas Booth Iwan Rheon Machine Gun Kelly Jef...
# 5848  Mel Gibson Vince Vaughn Michael Jai White S. C...
# 5849  Colin Farrell Michael Keaton Danny DeVito Tim ...
# 5850  Matthew McConaughey Zac Efron Jonah Hill Harmo...
# 5851  Ashley Bratcher Brooks Ryan Robia Scott Chuck ...
#
# [5852 rows x 7 columns]

# %%
final_df.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# comb             0
# dtype: int64

# %%
final_df.to_csv('final.csv',index=False)
